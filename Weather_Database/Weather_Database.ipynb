# %%
import pandas as pd
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 776

# %%
import time
from datetime import datetime

# %%
import requests
from config import weather_api_key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
        # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | utena
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | sitka
# Processing Record 6 of Set 1 | makakilo city
# Processing Record 7 of Set 1 | ovalle
# Processing Record 8 of Set 1 | neepawa
# Processing Record 9 of Set 1 | estancia velha
# Processing Record 10 of Set 1 | mogadishu
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | elk city
# Processing Record 14 of Set 1 | koslan
# Processing Record 15 of Set 1 | buala
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | bathsheba
# Processing Record 18 of Set 1 | codrington
# Processing Record 19 of Set 1 | samarai
# Processing Record 20 of Set 1 | port hardy
# Processing Record 21 of Set 1 | knysna
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | kaitangata
# Processing Record 27 of Set 1 | male
# Processing Record 28 of Set 1 | sao joao da barra
# Processing Record 29 of Set 1 | mvuma
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | nizhniy tsasuchey
# Processing Record 32 of Set 1 | zeya
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | diffa
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | cidreira
# Processing Record 38 of Set 1 | bulawayo
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | huanren
# Processing Record 41 of Set 1 | kimbe
# Processing Record 42 of Set 1 | hamilton
# Processing Record 43 of Set 1 | grindavik
# Processing Record 44 of Set 1 | kloulklubed
# Processing Record 45 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 1 | beisfjord
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | luderitz
# Processing Record 50 of Set 1 | khatanga
# Processing Record 1 of Set 2 | katsuura
# Processing Record 2 of Set 2 | limpapa
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 2 | xining
# Processing Record 8 of Set 2 | inirida
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | omboue
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | sioux lookout
# Processing Record 14 of Set 2 | sovetskiy
# Processing Record 15 of Set 2 | ponta do sol
# Processing Record 16 of Set 2 | mount pleasant
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | kruisfontein
# Processing Record 19 of Set 2 | quelimane
# Processing Record 20 of Set 2 | nakamura
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | black river
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | makubetsu
# Processing Record 25 of Set 2 | benicarlo
# Processing Record 26 of Set 2 | cayenne
# Processing Record 27 of Set 2 | disna
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 2 | zhitikara
# City not found. Skipping...
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | okhotsk
# Processing Record 33 of Set 2 | malibu
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | moose factory
# Processing Record 36 of Set 2 | zyryanka
# Processing Record 37 of Set 2 | deputatskiy
# Processing Record 38 of Set 2 | le vauclin
# Processing Record 39 of Set 2 | hami
# Processing Record 40 of Set 2 | harper
# Processing Record 41 of Set 2 | antofagasta
# Processing Record 42 of Set 2 | san jose de guanipa
# Processing Record 43 of Set 2 | ancud
# Processing Record 44 of Set 2 | nurota
# Processing Record 45 of Set 2 | itapirapua
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | bagli
# Processing Record 48 of Set 2 | lubango
# Processing Record 49 of Set 2 | kandrian
# Processing Record 50 of Set 2 | nampula
# Processing Record 1 of Set 3 | mahebourg
# Processing Record 2 of Set 3 | bagotville
# Processing Record 3 of Set 3 | uyuni
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | palmer
# Processing Record 6 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 3 | liverpool
# Processing Record 8 of Set 3 | yellowknife
# Processing Record 9 of Set 3 | dingle
# Processing Record 10 of Set 3 | twin falls
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 3 | la ronge
# Processing Record 13 of Set 3 | jamestown
# Processing Record 14 of Set 3 | sur
# Processing Record 15 of Set 3 | fairbanks
# Processing Record 16 of Set 3 | puerto carreno
# Processing Record 17 of Set 3 | rawson
# Processing Record 18 of Set 3 | hovd
# Processing Record 19 of Set 3 | srednekolymsk
# Processing Record 20 of Set 3 | erzin
# Processing Record 21 of Set 3 | norden
# Processing Record 22 of Set 3 | dovers
# Processing Record 23 of Set 3 | goderich
# Processing Record 24 of Set 3 | tuatapere
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | henties bay
# Processing Record 28 of Set 3 | lexington
# Processing Record 29 of Set 3 | pemba
# Processing Record 30 of Set 3 | leningradskiy
# Processing Record 31 of Set 3 | saskylakh
# Processing Record 32 of Set 3 | pedernales
# Processing Record 33 of Set 3 | paraguacu paulista
# Processing Record 34 of Set 3 | pisco
# Processing Record 35 of Set 3 | takoradi
# Processing Record 36 of Set 3 | margate
# Processing Record 37 of Set 3 | charcas
# Processing Record 38 of Set 3 | yinchuan
# Processing Record 39 of Set 3 | hambantota
# Processing Record 40 of Set 3 | leshukonskoye
# Processing Record 41 of Set 3 | pizarro
# Processing Record 42 of Set 3 | kapaa
# Processing Record 43 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 3 | banjar
# Processing Record 45 of Set 3 | east london
# Processing Record 46 of Set 3 | iqaluit
# Processing Record 47 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 3 | haicheng
# Processing Record 49 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 50 of Set 3 | ler
# Processing Record 1 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 4 | ziro
# Processing Record 3 of Set 4 | hasaki
# Processing Record 4 of Set 4 | sao filipe
# Processing Record 5 of Set 4 | grand gaube
# Processing Record 6 of Set 4 | zabaykalsk
# Processing Record 7 of Set 4 | taoudenni
# Processing Record 8 of Set 4 | torbay
# Processing Record 9 of Set 4 | atuona
# Processing Record 10 of Set 4 | kato milea
# Processing Record 11 of Set 4 | hithadhoo
# Processing Record 12 of Set 4 | barrow
# Processing Record 13 of Set 4 | rocha
# Processing Record 14 of Set 4 | urucara
# Processing Record 15 of Set 4 | lavrentiya
# Processing Record 16 of Set 4 | semey
# Processing Record 17 of Set 4 | tanete
# Processing Record 18 of Set 4 | nikolskoye
# Processing Record 19 of Set 4 | novoagansk
# Processing Record 20 of Set 4 | vila franca do campo
# Processing Record 21 of Set 4 | pecos
# Processing Record 22 of Set 4 | qaanaaq
# Processing Record 23 of Set 4 | port hedland
# Processing Record 24 of Set 4 | barreiras
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | gravdal
# Processing Record 27 of Set 4 | labuhan
# Processing Record 28 of Set 4 | andreyevo
# Processing Record 29 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 4 | airai
# Processing Record 31 of Set 4 | nivala
# Processing Record 32 of Set 4 | butaritari
# Processing Record 33 of Set 4 | ostersund
# Processing Record 34 of Set 4 | jaque
# Processing Record 35 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 4 | esmeraldas
# Processing Record 38 of Set 4 | jijiga
# Processing Record 39 of Set 4 | puerto del rosario
# Processing Record 40 of Set 4 | shubarshi
# Processing Record 41 of Set 4 | chapleau
# Processing Record 42 of Set 4 | mayo
# Processing Record 43 of Set 4 | carnarvon
# Processing Record 44 of Set 4 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 45 of Set 4 | gondar
# Processing Record 46 of Set 4 | egvekinot
# Processing Record 47 of Set 4 | gayny
# Processing Record 48 of Set 4 | yarada
# Processing Record 49 of Set 4 | tabas
# Processing Record 50 of Set 4 | pagman
# City not found. Skipping...
# Processing Record 1 of Set 5 | urumqi
# Processing Record 2 of Set 5 | constitucion
# Processing Record 3 of Set 5 | escanaba
# Processing Record 4 of Set 5 | tazovskiy
# Processing Record 5 of Set 5 | sistranda
# Processing Record 6 of Set 5 | altamira
# Processing Record 7 of Set 5 | upernavik
# Processing Record 8 of Set 5 | sola
# Processing Record 9 of Set 5 | niquero
# Processing Record 10 of Set 5 | belem de sao francisco
# Processing Record 11 of Set 5 | aswan
# Processing Record 12 of Set 5 | kavieng
# Processing Record 13 of Set 5 | biak
# Processing Record 14 of Set 5 | nishihara
# Processing Record 15 of Set 5 | flinders
# Processing Record 16 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 5 | saint-pierre
# Processing Record 18 of Set 5 | san luis
# Processing Record 19 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 5 | bubaque
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | muzhi
# Processing Record 23 of Set 5 | atar
# Processing Record 24 of Set 5 | kodiak
# Processing Record 25 of Set 5 | carutapera
# Processing Record 26 of Set 5 | gloversville
# Processing Record 27 of Set 5 | karratha
# Processing Record 28 of Set 5 | mount isa
# Processing Record 29 of Set 5 | penzance
# Processing Record 30 of Set 5 | ust-tsilma
# Processing Record 31 of Set 5 | cabedelo
# Processing Record 32 of Set 5 | whitehorse
# Processing Record 33 of Set 5 | shimoda
# Processing Record 34 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 35 of Set 5 | lalgudi
# Processing Record 36 of Set 5 | avera
# Processing Record 37 of Set 5 | vao
# Processing Record 38 of Set 5 | honiara
# Processing Record 39 of Set 5 | longyearbyen
# Processing Record 40 of Set 5 | bluff
# Processing Record 41 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 42 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 5 | chokurdakh
# Processing Record 44 of Set 5 | esperance
# Processing Record 45 of Set 5 | pangnirtung
# Processing Record 46 of Set 5 | paramonga
# Processing Record 47 of Set 5 | santa rosa
# Processing Record 48 of Set 5 | abalak
# Processing Record 49 of Set 5 | uige
# Processing Record 50 of Set 5 | edd
# Processing Record 1 of Set 6 | mackay
# Processing Record 2 of Set 6 | marabba
# Processing Record 3 of Set 6 | simao
# Processing Record 4 of Set 6 | terrace
# Processing Record 5 of Set 6 | villanueva de cordoba
# Processing Record 6 of Set 6 | ornskoldsvik
# Processing Record 7 of Set 6 | encruzilhada do sul
# Processing Record 8 of Set 6 | saldanha
# Processing Record 9 of Set 6 | nelson bay
# Processing Record 10 of Set 6 | puerto escondido
# Processing Record 11 of Set 6 | cervo
# Processing Record 12 of Set 6 | kuching
# Processing Record 13 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 6 | barsi
# Processing Record 15 of Set 6 | blyznyuky
# Processing Record 16 of Set 6 | ishigaki
# Processing Record 17 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 18 of Set 6 | jiwani
# Processing Record 19 of Set 6 | salalah
# Processing Record 20 of Set 6 | boa vista
# Processing Record 21 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 6 | sibolga
# Processing Record 23 of Set 6 | killybegs
# Processing Record 24 of Set 6 | pachino
# Processing Record 25 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 6 | sorland
# Processing Record 27 of Set 6 | hirara
# Processing Record 28 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 6 | ahipara
# Processing Record 30 of Set 6 | adre
# Processing Record 31 of Set 6 | anadyr
# Processing Record 32 of Set 6 | mentok
# City not found. Skipping...
# Processing Record 33 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 6 | makrana
# Processing Record 35 of Set 6 | saint-joseph
# Processing Record 36 of Set 6 | acarau
# Processing Record 37 of Set 6 | cockburn town
# Processing Record 38 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 6 | salgueiro
# Processing Record 40 of Set 6 | cabo san lucas
# Processing Record 41 of Set 6 | plettenberg bay
# Processing Record 42 of Set 6 | tual
# Processing Record 43 of Set 6 | bethel
# Processing Record 44 of Set 6 | talnakh
# Processing Record 45 of Set 6 | raudeberg
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | lugo
# Processing Record 48 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 6 | yelizovo
# Processing Record 50 of Set 6 | jesus carranza
# Processing Record 1 of Set 7 | tanout
# Processing Record 2 of Set 7 | narsaq
# Processing Record 3 of Set 7 | havre-saint-pierre
# Processing Record 4 of Set 7 | porto novo
# Processing Record 5 of Set 7 | tura
# Processing Record 6 of Set 7 | san patricio
# Processing Record 7 of Set 7 | port blair
# Processing Record 8 of Set 7 | nisia floresta
# Processing Record 9 of Set 7 | kalmunai
# Processing Record 10 of Set 7 | omsukchan
# Processing Record 11 of Set 7 | wanning
# Processing Record 12 of Set 7 | agadez
# Processing Record 13 of Set 7 | cherskiy
# Processing Record 14 of Set 7 | san rafael del sur
# Processing Record 15 of Set 7 | sept-iles
# Processing Record 16 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 7 | tarakan
# Processing Record 18 of Set 7 | wote
# Processing Record 19 of Set 7 | vardo
# Processing Record 20 of Set 7 | hauterive
# Processing Record 21 of Set 7 | garcia hernandez
# Processing Record 22 of Set 7 | nuuk
# Processing Record 23 of Set 7 | alice springs
# Processing Record 24 of Set 7 | pathein
# Processing Record 25 of Set 7 | pevek
# Processing Record 26 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 27 of Set 7 | faanui
# Processing Record 28 of Set 7 | antalaha
# Processing Record 29 of Set 7 | cozumel
# Processing Record 30 of Set 7 | kamskiye polyany
# Processing Record 31 of Set 7 | san cristobal
# Processing Record 32 of Set 7 | asau
# Processing Record 33 of Set 7 | madimba
# Processing Record 34 of Set 7 | sawakin
# Processing Record 35 of Set 7 | kyzyl-suu
# Processing Record 36 of Set 7 | palmares do sul
# Processing Record 37 of Set 7 | boke
# Processing Record 38 of Set 7 | vestmanna
# Processing Record 39 of Set 7 | santa rosalia
# Processing Record 40 of Set 7 | mangai
# Processing Record 41 of Set 7 | dambulla
# Processing Record 42 of Set 7 | san jose
# Processing Record 43 of Set 7 | hede
# Processing Record 44 of Set 7 | bandundu
# Processing Record 45 of Set 7 | meulaboh
# Processing Record 46 of Set 7 | otorohanga
# Processing Record 47 of Set 7 | amloh
# Processing Record 48 of Set 7 | richards bay
# Processing Record 49 of Set 7 | kargasok
# Processing Record 50 of Set 7 | castro
# Processing Record 1 of Set 8 | maldonado
# Processing Record 2 of Set 8 | zhuozhou
# City not found. Skipping...
# Processing Record 3 of Set 8 | trinidad
# Processing Record 4 of Set 8 | celestun
# Processing Record 5 of Set 8 | veraval
# Processing Record 6 of Set 8 | lauterbach
# Processing Record 7 of Set 8 | sambava
# Processing Record 8 of Set 8 | fortuna
# Processing Record 9 of Set 8 | bathurst
# Processing Record 10 of Set 8 | port augusta
# Processing Record 11 of Set 8 | villa union
# Processing Record 12 of Set 8 | mrakovo
# Processing Record 13 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 8 | george
# Processing Record 15 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 8 | lorengau
# Processing Record 17 of Set 8 | araxa
# Processing Record 18 of Set 8 | tiksi
# Processing Record 19 of Set 8 | jian
# Processing Record 20 of Set 8 | lincoln
# Processing Record 21 of Set 8 | tasiilaq
# Processing Record 22 of Set 8 | kawardha
# Processing Record 23 of Set 8 | fomboni
# Processing Record 24 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 8 | gualeguay
# Processing Record 26 of Set 8 | norman wells
# Processing Record 27 of Set 8 | kalevala
# Processing Record 28 of Set 8 | bambous virieux
# Processing Record 29 of Set 8 | zhigansk
# Processing Record 30 of Set 8 | alofi
# Processing Record 31 of Set 8 | banfora
# Processing Record 32 of Set 8 | lata
# Processing Record 33 of Set 8 | saint george
# Processing Record 34 of Set 8 | shelburne
# Processing Record 35 of Set 8 | lompoc
# Processing Record 36 of Set 8 | severo-yeniseyskiy
# Processing Record 37 of Set 8 | fort nelson
# Processing Record 38 of Set 8 | belle fourche
# Processing Record 39 of Set 8 | roswell
# Processing Record 40 of Set 8 | jalu
# Processing Record 41 of Set 8 | lebu
# Processing Record 42 of Set 8 | cortez
# Processing Record 43 of Set 8 | camana
# Processing Record 44 of Set 8 | champerico
# Processing Record 45 of Set 8 | namtsy
# Processing Record 46 of Set 8 | gusino
# Processing Record 47 of Set 8 | san carlos de bariloche
# Processing Record 48 of Set 8 | fort dodge
# Processing Record 49 of Set 8 | severo-kurilsk
# Processing Record 50 of Set 8 | along
# Processing Record 1 of Set 9 | pacific grove
# Processing Record 2 of Set 9 | talaya
# Processing Record 3 of Set 9 | ahumada
# City not found. Skipping...
# Processing Record 4 of Set 9 | denau
# City not found. Skipping...
# Processing Record 5 of Set 9 | camacha
# Processing Record 6 of Set 9 | porto walter
# Processing Record 7 of Set 9 | pleasanton
# Processing Record 8 of Set 9 | tymovskoye
# Processing Record 9 of Set 9 | bambanglipuro
# Processing Record 10 of Set 9 | jumla
# Processing Record 11 of Set 9 | the valley
# Processing Record 12 of Set 9 | longido
# Processing Record 13 of Set 9 | marawi
# Processing Record 14 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 9 | juneau
# Processing Record 16 of Set 9 | alamos
# Processing Record 17 of Set 9 | suntar
# Processing Record 18 of Set 9 | caravelas
# Processing Record 19 of Set 9 | naze
# Processing Record 20 of Set 9 | mumford
# Processing Record 21 of Set 9 | mandan
# Processing Record 22 of Set 9 | chapais
# Processing Record 23 of Set 9 | aksu
# Processing Record 24 of Set 9 | turka
# Processing Record 25 of Set 9 | roma
# Processing Record 26 of Set 9 | nyurba
# Processing Record 27 of Set 9 | kawana waters
# City not found. Skipping...
# Processing Record 28 of Set 9 | bereda
# Processing Record 29 of Set 9 | banda
# Processing Record 30 of Set 9 | teya
# Processing Record 31 of Set 9 | makhinjauri
# Processing Record 32 of Set 9 | san quintin
# Processing Record 33 of Set 9 | nacala
# Processing Record 34 of Set 9 | chara
# Processing Record 35 of Set 9 | sergeyevka
# Processing Record 36 of Set 9 | bucerias
# Processing Record 37 of Set 9 | poum
# Processing Record 38 of Set 9 | panalingaan
# Processing Record 39 of Set 9 | panzhihua
# Processing Record 40 of Set 9 | nalut
# Processing Record 41 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 42 of Set 9 | san ramon
# Processing Record 43 of Set 9 | danville
# Processing Record 44 of Set 9 | prince rupert
# Processing Record 45 of Set 9 | port lincoln
# Processing Record 46 of Set 9 | sigli
# Processing Record 47 of Set 9 | riyadh
# Processing Record 48 of Set 9 | san benito
# Processing Record 49 of Set 9 | solnechnyy
# Processing Record 50 of Set 9 | vanimo
# Processing Record 1 of Set 10 | old road
# City not found. Skipping...
# Processing Record 2 of Set 10 | haines junction
# Processing Record 3 of Set 10 | port-gentil
# Processing Record 4 of Set 10 | nanortalik
# Processing Record 5 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 6 of Set 10 | belaya gora
# Processing Record 7 of Set 10 | taldan
# Processing Record 8 of Set 10 | bay roberts
# Processing Record 9 of Set 10 | fuerte olimpo
# Processing Record 10 of Set 10 | channel-port aux basques
# Processing Record 11 of Set 10 | santa cruz
# Processing Record 12 of Set 10 | vanavara
# Processing Record 13 of Set 10 | korla
# Processing Record 14 of Set 10 | hualmay
# Processing Record 15 of Set 10 | sabang
# Processing Record 16 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 17 of Set 10 | tautira
# Processing Record 18 of Set 10 | jawhar
# Processing Record 19 of Set 10 | victoria
# Processing Record 20 of Set 10 | baghmara
# Processing Record 21 of Set 10 | kenai
# Processing Record 22 of Set 10 | vila
# Processing Record 23 of Set 10 | karla
# Processing Record 24 of Set 10 | lakes entrance
# Processing Record 25 of Set 10 | banda aceh
# Processing Record 26 of Set 10 | marsh harbour
# Processing Record 27 of Set 10 | talara
# Processing Record 28 of Set 10 | muroto
# Processing Record 29 of Set 10 | katherine
# Processing Record 30 of Set 10 | pacos de brandao
# Processing Record 31 of Set 10 | erzurum
# Processing Record 32 of Set 10 | comarapa
# Processing Record 33 of Set 10 | ust-omchug
# Processing Record 34 of Set 10 | beyneu
# Processing Record 35 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 36 of Set 10 | bonfim
# Processing Record 37 of Set 10 | samana
# Processing Record 38 of Set 10 | vila velha
# Processing Record 39 of Set 10 | lake havasu city
# Processing Record 40 of Set 10 | portland
# Processing Record 41 of Set 10 | srandakan
# Processing Record 42 of Set 10 | mahajanga
# Processing Record 43 of Set 10 | puerto baquerizo moreno
# Processing Record 44 of Set 10 | maralal
# Processing Record 45 of Set 10 | dongfeng
# Processing Record 46 of Set 10 | evensk
# Processing Record 47 of Set 10 | carmo do paranaiba
# Processing Record 48 of Set 10 | medea
# Processing Record 49 of Set 10 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 1 of Set 11 | richmond
# Processing Record 2 of Set 11 | oranjemund
# Processing Record 3 of Set 11 | ostuacan
# Processing Record 4 of Set 11 | itarema
# Processing Record 5 of Set 11 | kholodnyy
# Processing Record 6 of Set 11 | kirakira
# Processing Record 7 of Set 11 | seydi
# Processing Record 8 of Set 11 | daru
# Processing Record 9 of Set 11 | branesti
# Processing Record 10 of Set 11 | innisfail
# Processing Record 11 of Set 11 | ocampo
# Processing Record 12 of Set 11 | amarante do maranhao
# Processing Record 13 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 14 of Set 11 | tiarei
# Processing Record 15 of Set 11 | timmins
# Processing Record 16 of Set 11 | ponta delgada
# Processing Record 17 of Set 11 | ciudad bolivar
# Processing Record 18 of Set 11 | vangaindrano
# Processing Record 19 of Set 11 | muncar
# Processing Record 20 of Set 11 | analipsis
# Processing Record 21 of Set 11 | qandala
# Processing Record 22 of Set 11 | takaungu
# Processing Record 23 of Set 11 | batasan
# Processing Record 24 of Set 11 | sokoni
# Processing Record 25 of Set 11 | florence
# Processing Record 26 of Set 11 | namibe
# Processing Record 27 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 28 of Set 11 | nambucca heads
# Processing Record 29 of Set 11 | carbonia
# Processing Record 30 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 31 of Set 11 | limoeiro do ajuru
# Processing Record 32 of Set 11 | xichang
# Processing Record 33 of Set 11 | yar-sale
# Processing Record 34 of Set 11 | irara
# Processing Record 35 of Set 11 | tolaga bay
# Processing Record 36 of Set 11 | broken hill
# Processing Record 37 of Set 11 | matara
# Processing Record 38 of Set 11 | rundu
# Processing Record 39 of Set 11 | eureka
# Processing Record 40 of Set 11 | maniitsoq
# Processing Record 41 of Set 11 | los llanos de aridane
# Processing Record 42 of Set 11 | aklavik
# Processing Record 43 of Set 11 | sobolevo
# Processing Record 44 of Set 11 | boralday
# Processing Record 45 of Set 11 | esna
# Processing Record 46 of Set 11 | adrar
# Processing Record 47 of Set 11 | santa rita
# Processing Record 48 of Set 11 | ucluelet
# Processing Record 49 of Set 11 | brae
# Processing Record 50 of Set 11 | norfolk
# Processing Record 1 of Set 12 | ostrovnoy
# Processing Record 2 of Set 12 | husavik
# Processing Record 3 of Set 12 | manicore
# Processing Record 4 of Set 12 | fano
# Processing Record 5 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 6 of Set 12 | port hueneme
# Processing Record 7 of Set 12 | songjianghe
# Processing Record 8 of Set 12 | praia
# Processing Record 9 of Set 12 | lidkoping
# Processing Record 10 of Set 12 | surgut
# Processing Record 11 of Set 12 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 12 of Set 12 | svetlaya
# Processing Record 13 of Set 12 | tabukiniberu
# City not found. Skipping...
# Processing Record 14 of Set 12 | ajdabiya
# Processing Record 15 of Set 12 | baft
# Processing Record 16 of Set 12 | jambi
# Processing Record 17 of Set 12 | chicama
# Processing Record 18 of Set 12 | ingham
# Processing Record 19 of Set 12 | dakar
# Processing Record 20 of Set 12 | waipawa
# Processing Record 21 of Set 12 | hobyo
# Processing Record 22 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 12 | mattru
# Processing Record 24 of Set 12 | wattegama
# Processing Record 25 of Set 12 | pishin
# Processing Record 26 of Set 12 | yulara
# Processing Record 27 of Set 12 | sorong
# Processing Record 28 of Set 12 | souillac
# Processing Record 29 of Set 12 | progreso
# Processing Record 30 of Set 12 | umm kaddadah
# Processing Record 31 of Set 12 | puri
# Processing Record 32 of Set 12 | hargeysa
# Processing Record 33 of Set 12 | kavaratti
# Processing Record 34 of Set 12 | vryburg
# Processing Record 35 of Set 12 | torfyanoy
# Processing Record 36 of Set 12 | creel
# Processing Record 37 of Set 12 | namwala
# Processing Record 38 of Set 12 | khetri
# Processing Record 39 of Set 12 | pangai
# Processing Record 40 of Set 12 | ulagan
# Processing Record 41 of Set 12 | zhuhai
# Processing Record 42 of Set 12 | christiana
# Processing Record 43 of Set 12 | martil
# Processing Record 44 of Set 12 | sakakah
# Processing Record 45 of Set 12 | fort-shevchenko
# Processing Record 46 of Set 12 | scunthorpe
# Processing Record 47 of Set 12 | ilulissat
# Processing Record 48 of Set 12 | arman
# Processing Record 49 of Set 12 | bilibino
# Processing Record 50 of Set 12 | itapuranga
# Processing Record 1 of Set 13 | coshocton
# Processing Record 2 of Set 13 | ferrol
# Processing Record 3 of Set 13 | minsk
# Processing Record 4 of Set 13 | la palma
# Processing Record 5 of Set 13 | half moon bay
# Processing Record 6 of Set 13 | kolondieba
# Processing Record 7 of Set 13 | nyakahanga
# Processing Record 8 of Set 13 | otjimbingwe
# Processing Record 9 of Set 13 | gat
# Processing Record 10 of Set 13 | road town
# Processing Record 11 of Set 13 | hailar
# Processing Record 12 of Set 13 | laguna
# Processing Record 13 of Set 13 | cancun
# Processing Record 14 of Set 13 | pringsewu
# Processing Record 15 of Set 13 | ambilobe
# Processing Record 16 of Set 13 | foumban
# Processing Record 17 of Set 13 | solwezi
# Processing Record 18 of Set 13 | thinadhoo
# Processing Record 19 of Set 13 | lasa
# Processing Record 20 of Set 13 | camocim
# Processing Record 21 of Set 13 | megion
# Processing Record 22 of Set 13 | vilyuysk
# Processing Record 23 of Set 13 | lunsar
# Processing Record 24 of Set 13 | chifeng
# Processing Record 25 of Set 13 | inhambane
# Processing Record 26 of Set 13 | dongobesh
# Processing Record 27 of Set 13 | jinzhou
# Processing Record 28 of Set 13 | coxim
# Processing Record 29 of Set 13 | gobo
# Processing Record 30 of Set 13 | chumikan
# Processing Record 31 of Set 13 | dole
# Processing Record 32 of Set 13 | buraydah
# Processing Record 33 of Set 13 | machilipatnam
# Processing Record 34 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 13 | zhezkazgan
# Processing Record 36 of Set 13 | scottsboro
# Processing Record 37 of Set 13 | oranjestad
# Processing Record 38 of Set 13 | pinawa
# Processing Record 39 of Set 13 | tomatlan
# Processing Record 40 of Set 13 | mongagua
# Processing Record 41 of Set 13 | turan
# Processing Record 42 of Set 13 | wawa
# Processing Record 43 of Set 13 | sonoma
# Processing Record 44 of Set 13 | preobrazheniye
# Processing Record 45 of Set 13 | north platte
# Processing Record 46 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 13 | birao
# Processing Record 48 of Set 13 | cuamba
# Processing Record 49 of Set 13 | nadym
# Processing Record 50 of Set 13 | saint-ambroise
# Processing Record 1 of Set 14 | kumluca
# Processing Record 2 of Set 14 | okha
# Processing Record 3 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 4 of Set 14 | linxia
# Processing Record 5 of Set 14 | novochernorechenskiy
# Processing Record 6 of Set 14 | luba
# Processing Record 7 of Set 14 | te anau
# Processing Record 8 of Set 14 | klaksvik
# Processing Record 9 of Set 14 | pilar
# Processing Record 10 of Set 14 | broome
# Processing Record 11 of Set 14 | isangel
# Processing Record 12 of Set 14 | lujan
# Processing Record 13 of Set 14 | vestmannaeyjar
# Processing Record 14 of Set 14 | lagoa
# Processing Record 15 of Set 14 | faya
# Processing Record 16 of Set 14 | udachnyy
# Processing Record 17 of Set 14 | russell
# Processing Record 18 of Set 14 | banon
# Processing Record 19 of Set 14 | high rock
# Processing Record 20 of Set 14 | havoysund
# Processing Record 21 of Set 14 | kolaras
# Processing Record 22 of Set 14 | veinticinco de mayo
# Processing Record 23 of Set 14 | sol-iletsk
# Processing Record 24 of Set 14 | oistins
# Processing Record 25 of Set 14 | mama
# Processing Record 26 of Set 14 | beringovskiy
# Processing Record 27 of Set 14 | naruja
# Processing Record 28 of Set 14 | kampot
# Processing Record 29 of Set 14 | puerto maldonado
# Processing Record 30 of Set 14 | kisangani
# Processing Record 31 of Set 14 | pandan
# Processing Record 32 of Set 14 | coos bay
# Processing Record 33 of Set 14 | den helder
# Processing Record 34 of Set 14 | bushehr
# Processing Record 35 of Set 14 | meadow lake
# Processing Record 36 of Set 14 | kahului
# Processing Record 37 of Set 14 | kosh-agach
# Processing Record 38 of Set 14 | svetlyy
# Processing Record 39 of Set 14 | schluchtern
# Processing Record 40 of Set 14 | winslow
# Processing Record 41 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 14 | pavlodar
# Processing Record 43 of Set 14 | dalby
# Processing Record 44 of Set 14 | perelyub
# Processing Record 45 of Set 14 | ndola
# Processing Record 46 of Set 14 | oriximina
# Processing Record 47 of Set 14 | santa maria
# Processing Record 48 of Set 14 | kapoeta
# Processing Record 49 of Set 14 | moerai
# Processing Record 50 of Set 14 | perigueux
# Processing Record 1 of Set 15 | pangkalanbuun
# Processing Record 2 of Set 15 | san juan
# Processing Record 3 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 15 | dalian
# Processing Record 5 of Set 15 | lensk
# Processing Record 6 of Set 15 | os
# City not found. Skipping...
# Processing Record 7 of Set 15 | gikongoro
# Processing Record 8 of Set 15 | wolfville
# Processing Record 9 of Set 15 | safaga
# Processing Record 10 of Set 15 | carangola
# Processing Record 11 of Set 15 | dongkan
# Processing Record 12 of Set 15 | ginir
# Processing Record 13 of Set 15 | casper
# Processing Record 14 of Set 15 | gamay
# Processing Record 15 of Set 15 | ous
# Processing Record 16 of Set 15 | garm
# City not found. Skipping...
# Processing Record 17 of Set 15 | marapanim
# Processing Record 18 of Set 15 | isabela
# Processing Record 19 of Set 15 | roanoke rapids
# Processing Record 20 of Set 15 | masvingo
# Processing Record 21 of Set 15 | oktyabrskoye
# Processing Record 22 of Set 15 | tygda
# Processing Record 23 of Set 15 | garowe
# Processing Record 24 of Set 15 | coruripe
# Processing Record 25 of Set 15 | baruun-urt
# Processing Record 26 of Set 15 | sembe
# Processing Record 27 of Set 15 | morondava
# Processing Record 28 of Set 15 | chioggia
# Processing Record 29 of Set 15 | dicabisagan
# Processing Record 30 of Set 15 | portel
# Processing Record 31 of Set 15 | rosetta
# Processing Record 32 of Set 15 | mount gambier
# Processing Record 33 of Set 15 | skibbereen
# Processing Record 34 of Set 15 | muisne
# Processing Record 35 of Set 15 | gondanglegi
# Processing Record 36 of Set 15 | seybaplaya
# Processing Record 37 of Set 15 | khudumelapye
# Processing Record 38 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 15 | roquetas de mar
# Processing Record 40 of Set 15 | boguchany
# Processing Record 41 of Set 15 | strezhevoy
# Processing Record 42 of Set 15 | uruzgan
# Processing Record 43 of Set 15 | gibsons
# Processing Record 44 of Set 15 | sisimiut
# Processing Record 45 of Set 15 | yerbogachen
# Processing Record 46 of Set 15 | valley city
# Processing Record 47 of Set 15 | daura
# Processing Record 48 of Set 15 | yenagoa
# Processing Record 49 of Set 15 | castro verde
# Processing Record 50 of Set 15 | yaan
# Processing Record 1 of Set 16 | manakara
# Processing Record 2 of Set 16 | felidhoo
# City not found. Skipping...
# Processing Record 3 of Set 16 | mundo nuevo
# Processing Record 4 of Set 16 | tianpeng
# Processing Record 5 of Set 16 | kodinsk
# Processing Record 6 of Set 16 | shenjiamen
# Processing Record 7 of Set 16 | voyvozh
# Processing Record 8 of Set 16 | solovetskiy
# City not found. Skipping...
# Processing Record 9 of Set 16 | abnub
# Processing Record 10 of Set 16 | viesite
# Processing Record 11 of Set 16 | mardin
# Processing Record 12 of Set 16 | malartic
# Processing Record 13 of Set 16 | west point
# Processing Record 14 of Set 16 | komsomolskiy
# Processing Record 15 of Set 16 | axim
# Processing Record 16 of Set 16 | manado
# Processing Record 17 of Set 16 | matsanga
# City not found. Skipping...
# Processing Record 18 of Set 16 | rudbar
# Processing Record 19 of Set 16 | kawalu
# Processing Record 20 of Set 16 | yambio
# Processing Record 21 of Set 16 | aasiaat
# Processing Record 22 of Set 16 | north bend
# Processing Record 23 of Set 16 | itoman
# Processing Record 24 of Set 16 | tarko-sale
# Processing Record 25 of Set 16 | ukiah
# Processing Record 26 of Set 16 | anori
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Ribeira Grande  38.5167  -28.7000     56.75        67          31
# 1           Hobart -42.8794  147.3294     61.27        88          75
# 2            Utena  55.5000   25.6000     33.71        79           5
# 3  Arraial Do Cabo -22.9661  -42.0278     76.86        94           0
# 4            Sitka  57.0531 -135.3300     42.69        65          40
# 5    Makakilo City  21.3469 -158.0858     80.92        55         100
# 6           Ovalle -30.5983  -71.2003     75.79        37           0
# 7          Neepawa  50.2289  -99.4664     49.30        51          95
# 8   Estancia Velha -29.6483  -51.1739     73.90        84          63
# 9        Mogadishu   2.0371   45.3438     81.43        75          72
#
#    Wind Speed Country Current Description
# 0       37.13      PT    scattered clouds
# 1        3.44      AU       broken clouds
# 2        7.65      LT           clear sky
# 3        9.22      BR           clear sky
# 4        8.05      US    scattered clouds
# 5       17.27      US     overcast clouds
# 6        6.51      CL           clear sky
# 7       12.10      CA     overcast clouds
# 8        3.49      BR       broken clouds
# 9       14.45      SO       broken clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Ribeira Grande      PT  38.5167  -28.7000     56.75        67          31
# 1           Hobart      AU -42.8794  147.3294     61.27        88          75
# 2            Utena      LT  55.5000   25.6000     33.71        79           5
# 3  Arraial Do Cabo      BR -22.9661  -42.0278     76.86        94           0
# 4            Sitka      US  57.0531 -135.3300     42.69        65          40
# 5    Makakilo City      US  21.3469 -158.0858     80.92        55         100
# 6           Ovalle      CL -30.5983  -71.2003     75.79        37           0
# 7          Neepawa      CA  50.2289  -99.4664     49.30        51          95
# 8   Estancia Velha      BR -29.6483  -51.1739     73.90        84          63
# 9        Mogadishu      SO   2.0371   45.3438     81.43        75          72
#
#    Wind Speed Current Description
# 0       37.13    scattered clouds
# 1        3.44       broken clouds
# 2        7.65           clear sky
# 3        9.22           clear sky
# 4        8.05    scattered clouds
# 5       17.27     overcast clouds
# 6        6.51           clear sky
# 7       12.10     overcast clouds
# 8        3.49       broken clouds
# 9       14.45       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
